# %% [markdown]
# # Linear Regression Model - Home Pricing Prediction

# %% [markdown]
# ###  Importing Packages

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model
import numpy as np

# %% [markdown]
# ### Reading Data

# %%
df = pd.read_excel("C:\Code3\dataset.xlsx")
df
# Out:
#       Area      SalePrice
# 0     1461  169277.052498
# 1     1462  187758.393989
# 2     1463  183583.683570
# 3     1464  179317.477511
# 4     1465  150730.079977
# ...    ...            ...
# 1454  2915  167081.220949
# 1455  2916  164788.778231
# 1456  2917  219222.423400
# 1457  2918  184924.279659
# 1458  2919  187741.866657
#
# [1459 rows x 2 columns]

# %%
# %matplotlib inline

# %%
plt.scatter(df.Area, df.SalePrice, color='purple', marker='+')
plt.xlabel('Area Sq ft. ')
plt.ylabel('Sale Price $')
# Out:
# Text(0, 0.5, 'Sale Price $')

# %% [markdown]
# ### Building Linear Regression Model

# %%
reg_lin = linear_model.LinearRegression()
reg_lin.fit(df[['Area']], df.SalePrice)
# Out:
# LinearRegression()

# %%
reg_lin.predict(np.array([3300]).reshape(-1, 1))
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([184674.42946885])

# %%
# %matplotlib inline
plt.scatter(df.Area, df.SalePrice, color='red', marker='+')
plt.xlabel('Area Sq ft. ')
plt.ylabel('Sale Price $')
plt.plot(df.Area, reg_lin.predict(df[['Area']]), color='blue')

# %%
a = pd.read_csv("C:\\Code3\\areas.csv")
a.head()
# Out:
#    Area
# 0  1461
# 1  1462
# 2  1463
# 3  1464
# 4  1465

# %%
predict = reg_lin.predict(a)
predict
# Out:
# array([175577.98789681, 175582.93430332, 175587.88070983, ...,
#        182779.95577549, 182784.902182  , 182789.84858851])

# %%
a['SalePrice'] = predict

# %%
a
# Out:
#       Area      SalePrice
# 0     1461  175577.987897
# 1     1462  175582.934303
# 2     1463  175587.880710
# 3     1464  175592.827116
# 4     1465  175597.773523
# ...    ...            ...
# 1454  2915  182770.062962
# 1455  2916  182775.009369
# 1456  2917  182779.955775
# 1457  2918  182784.902182
# 1458  2919  182789.848589
#
# [1459 rows x 2 columns]

# %%
a.to_csv("predictions.csv", index=False)
